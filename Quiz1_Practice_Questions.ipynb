# %% [markdown]
# # Practice Problems for Quiz \#1

# %%
import math
import random
import statistics
import matplotlib.pyplot as plt

# %% [markdown]
# <b>Preamble:</b> This section is what I would give you on the quiz, to help you get the list of lists into memory. You will be working with a different version of the SEC master index, so you will need to download that file and I will tweak the file name under input().
#
# <b>Note: The actual quiz will be much shorter. Probably two questions related to list of lists and then a couple of questions related to a single simulation.</b>

# %%
def input(file):
    f = open(file, 'r')
    lines = f.readlines()   # convert file into a list of lines
    f.close()
    return lines

# %%
sec = input('1.4_SEC_master_2024_Q3_sub.txt')

# %%
sec = sec[11:]

# %%
len(sec)

# %%
lol = []
for r in sec:
    data = r.strip().split('|')
    lol.append(data)

# %%
lol[0]

# %% [markdown]
# ## PROCESSING LIST OF LISTS

# %% [markdown]
# <b>Question 1:</b> How many different CIKs filed a plain vanilla 8-K during 2025Q2? Count each CIK once.

# %%
# your code goes here

# %% [markdown]
# <b>Question 2:</b> How many filings are filed on the 15th day of April or May? Which day had more filings?

# %%
# your code goes here

# %% [markdown]
# <b>Question 3:</b> Which CIK filed the most plain vanilla 8-Ks during 2025Q2?
#
# Hint: Start by excluding rows with filings other than '8-K' so that the .count() function doesn't get overwhelmed

# %%
# your code goes here

# %% [markdown]
# <b>Question 4:</b> How many of the SEC forms begin with the letter N (which stands for Investment)? <b>Only count each form type once.</b>

# %%
# your code goes here

# %% [markdown]
# <b>Question 5:</b> Calculate the standard deviation of the CIK values (after converting to integers). Duplicate CIK should be included in the calculation.

# %%
# your code goes here

# %% [markdown]
# <b>Question 6:</b> Pick a SEC form type at random using random.sample([list unique filings],1) where you need to create the list of unique filings, one obs per filing type. Count the number of times that form appears in 'lol' (not the list of unique filings)
#
# <b>Hint: random.sample() returns a list and you want a string</b>

# %%
help(random.sample)

# %%
# your code goes here

# %% [markdown]
# ## SIMULATIONS

# %% [markdown]
# <b>Question 7.</b> Estimate the probability that an asset with an expected annual return of 10% and standard deviation of 12% has a higher realized return than an asset with an expected annual return of 8% and standard deviation of 8%.

# %%
# your code goes here

# %% [markdown]
# <b>Question 8:</b> Simulate 3-year buy-and-hold returns for a financial asset with an expected annual return of 10% and annual standard deviation of 35%.
#
# - What is the probability of a negative 3-year cumulative net return?
# - What is the probability of a 3-year cumulative net return between 20% and 40%?
# - What is the probability of a positive 2-year cumulative net return but negative 3-year cumulative net return?
#
# <i>Hint: Answering the last question above requires you to follow portfolio values over time, not just focus on 3-year values.</i>

# %%
# your code goes here

# %% [markdown]
# <b>Question 9a:</b> Asset A has an expected annual return of 10% and standard deviation of 20%. Its returns are normally distributed but cannot be less than -100\%. Asset B is a derivative; its return is based on Asset A's return. Specifically,
#
# - if Asset A's return is $\le$ -10%, Asset B returns -10\%
# - if Asset A's return is $\ge$ 20%, Asset B returns 20%
# - otherwise Asset B offers the same return as Asset A.
#
# Please simulate the return of Asset B 10,000 times. How do the average annual return and standard deviation of annual returns of this derivative compare to those of Asset A?
#
# <i>Hint: It is easiest to create a function that transforms return A into return B and then use this function in list comprehension.</i>

# %%
# your code goes here

# %% [markdown]
# <b>Question 9b:</b> You plan to invest \\$1000 in either Asset A or Asset B. You have a fixed investment horizon of 1 year. Which asset has the higher expected utility if your utility function is $\sqrt{\text{portfolio value in year 1}}$? Which asset has the higher certainty equivalent? Justify your answer with the appropriate calculations.

# %%
# your code goes here

# %% [markdown]
# <b>Question 10:</b> A new financial product has the following payoff structure. You roll a 10-sides dice, containing the integers 0 through 9. Each number is equally likely and you receive \\$1000 times the number you roll as your payoff. Your utility function is given by math.sqrt()
#
# $U = \sqrt{\text{payoff}}$.
#
# What are the expected payoff, expected utility from this distribution of payoffs, and the corresponding certainty equivalent? Based on these answers, should you pay $4000 to roll the dice once?

# %%
# your code goes here
